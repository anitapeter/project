# %% [markdown]
# <a href="https://colab.research.google.com/github/anitapeter/pytorch-yolo-v3/blob/master/Object_detection_phase1_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from os.path import exists, join, basename, splitext

# %%
git_repo_url = 'https://github.com/anitapeter/pytorch-yolo-v3.git'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):
  # clone and install dependencies
  # !git clone -q $git_repo_url
  #!cd $project_name && pip install -q -r requirement.txt

# %%
import sys
sys.path.append(project_name)
import time
import matplotlib
import matplotlib.pylab as plt
plt.rcParams["axes.grid"] = False

# %%
if not exists('yolov3.weights'):
  # !wget -q https://pjreddie.com/media/files/yolov3.weights

# %%
IMAGE_URL = 'https://upload.wikimedia.org/wikipedia/commons/2/27/Black_white_cats.jpg'

# %%
image_file = basename(IMAGE_URL)
# !wget -q -O $image_file $IMAGE_URL
plt.imshow(matplotlib.image.imread(image_file))

# %%
# !cd pytorch-yolo-v3 && python detect.py --weights ../yolov3.weights --images ../$image_file --det ..
# Out:
# Loading network.....
# Network successfully loaded
# Black_white_cats.jpg predicted in  0.046 seconds
#
# ----------------------------------------------------------
#
# SUMMARY
# ----------------------------------------------------------
# Task                     : Time Taken (in seconds)
#
# Reading addresses        : 0.000
# Loading batch            : 0.080
# Detection (1 images)     : 0.048
# Output Processing        : 0.000
# Drawing Boxes            : 0.015
# Average time_per_img     : 0.144
# ----------------------------------------------------------

# %%
plt.figure(figsize=(20, 15))
plt.imshow(matplotlib.image.imread('det_%s' % image_file))

# %%
# !apt-get update
# Out:
# Get:1 https://download.docker.com/linux/ubuntu bionic InRelease [64.4 kB]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Err:1 https://download.docker.com/linux/ubuntu bionic InRelease
# ...

# %%
# !apt install apt-transport-https ca-certificates curl software-properties-common
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ca-certificates is already the newest version (20180409).
# curl is already the newest version (7.58.0-2ubuntu3.8).
# software-properties-common is already the newest version (0.96.24.32.12).
# apt-transport-https is already the newest version (1.6.12).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 85 not upgraded.

# %%
# !apt-get install apt-transport-https ca-certificates curl software-properties-common
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ca-certificates is already the newest version (20180409).
# curl is already the newest version (7.58.0-2ubuntu3.8).
# software-properties-common is already the newest version (0.96.24.32.12).
# apt-transport-https is already the newest version (1.6.12).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 85 not upgraded.

# %%
# !add-apt-repository "deb [arch=amd64] https://download.docker.com/linux/ubuntu bionic stable"
# Out:
# Get:1 https://download.docker.com/linux/ubuntu bionic InRelease [64.4 kB]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Err:1 https://download.docker.com/linux/ubuntu bionic InRelease
# ...

# %%
# !python rnn_words.py < pytorch-yolo-v3/result.txt
# Out:
# WARNING:tensorflow:From rnn_words.py:30: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Loaded training data...
# WARNING:tensorflow:From rnn_words.py:68: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From rnn_words.py:73: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From rnn_words.py:90: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From rnn_words.py:90: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
